# %%
# !pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting future (from ffmpeg-python)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Installing collected packages: future, ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0 future-1.0.0
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd

def trim_video(video_path, start, end, output_path):
    # Skip if already trimmed
    if os.path.exists(output_path):
        print(f"✅ Skipping {output_path}, already exists.")
        return
    
    # Skip if video not downloaded yet
    if not os.path.exists(video_path) or os.path.getsize(video_path) < 1_000_000:  # <1MB
        print(f"⚠️ Skipping {video_path}, file missing or incomplete.")
        return
    
    # Skip if timestamps invalid
    if end <= start:
        print(f"⚠️ Skipping {video_path}, invalid timestamps {start}-{end}")
        return

    try:
        (
            ffmpeg
            .input(video_path, ss=start, to=end)
            .output(output_path, vcodec="libx264", acodec="aac")
            .run(quiet=True, overwrite_output=True)
        )
        print(f"💾 Saved {output_path}")
    except Exception as e:
        print(f"❌ Error processing {video_path}: {e}")


# ---------- Loop through subset.csv ----------
subset = pd.read_csv("subset.csv")

for _, row in subset.iterrows():
    youtube_id = row['youtube_id']
    start = row['time_start']
    end = row['time_end']
    label = row['label'].replace(" ", "_")

    video_path = f"greenify_videos/{youtube_id}.mp4"
    output_path = f"dataset/trimmed_videos/{youtube_id}_{label}.mp4"

    trim_video(video_path, start, end, output_path)
# Out:
# ✅ Skipping dataset/trimmed_videos/-gswhyjdG-A_catching_or_throwing_baseball.mp4, already exists.
# ⚠️ Skipping greenify_videos/-i9n9qVTlmk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/-jIBrJAYBeg.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/-JLmaEHB_GI.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/-sKTm-mjHYo_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/-_o1wewuNhU.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/-_ZMybcaUOw_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/0-2GOSXJUe0.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/08Rk0r1zVyk_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/08sAVLdsWI4_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/0AcqN56Sn5A_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/0AO_OCEztlc_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/0f5VDpQ8V9c.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/0KgQ0m9WI2g_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/0MQ-i0IpRi4.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/0MXLuil0aOI.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/0UdpIwbUXZA_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/0zYjmT4vCzk_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/0_dWsMfL1LA.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/0_hOxBg1uNY_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/10PGtVHab70.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/1EaQEYibFek_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/1FcgfYYwHhc.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/1IhJMNd-GeQ.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/1kye_ygEMfc_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/1QoV0n38zhM.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/1RVKKlpsDhg.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/1SvzKT0TfKc_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/2-ivU3kCoaY.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/28XIKs1x3fw.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/2bDcWbe5r5g.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/2EsR9zAw7D8.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/2ixxIMTLsRU_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/2LfhzfiO0g0_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/2ly4hFzORFE.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/2qhYJ80-2-M_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/2vZvZMuPCuk.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/2YjE6XCkkSc_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/329RMoLHBnA.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/36hYpaUazJ0.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/37V1uQa2am4_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/3Ba4ljI7J9c_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/3cSYYBgXoJM_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/3kUYkcOupjo_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/3ObuX3a1uCA.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/3PG3Lb3OXT0_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/3Q8iDCfPV2E_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/3RbcDaYxrQw_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/3Z3bbgbypCo.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/44hB4DRfUcg_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/45P8ox6EX0o_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/4AKIma3sTr0.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/4WaqAOO6NH0_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/4ygsbn9GA_8.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/4YKUnTnBSTU.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/5aNInVANxJg.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/5mqCCqaGYD4_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/5MWbZcgmDlM_catching_or_throwing_baseball.mp4
# 💾 Saved dataset/trimmed_videos/5PbsQ3g33YQ_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/5_XT38PbwpQ.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/6afm3jt9PUg.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/6H2y3A-aZ5c.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos/6nfEVZaQX_o_catching_or_throwing_baseball.mp4
# ⚠️ Skipping greenify_videos/6p8YWWBe-o4.mp4, file missing or incomplete.
# 💾 Saved dataset/trimmed_videos
.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/xofIP95RV88.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/xp9IRXbSrfc.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/XPN_-VcGZaU.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/XQJeHYDSaGk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/xQVm2TOMWgE.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/xrs30g5bWck.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/xTTB0R0bIhU.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/XusQ3T98QAc.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/XWCN04lD-m4.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/xWL7wzhL-LU.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/xx48lwNoNmQ.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/XXISDDzcUMQ.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/XxXLPVYhmPE.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/XYEI-TfT4bM.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/x_bcqtP0498.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/y7TiUjOqAnY.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Y8G81Ms8OT8.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YaxXYUHV9t0.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YbeJLV9Cvyo.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YcUwb5BRR9Q.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YdBL7yW68sI.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YDe7XxJQnNM.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Ye-aKpKlhw8.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/yfa-Xx8zR9w.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/yFyYsGKGaAs.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YglEpdv9Nbk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YGq0ln8JHNA.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YI7YpWLFvpM.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YIoVrakZXHE.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YiXn1avKYIo.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YJr8XWZHD2M.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YK2fS1tGr1g.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ykmWVrYLXTk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ylCHcTSDqy0.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YM_WaViSdYo.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/yOKGYUP1w2I.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Yq0hkLXPeEw.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/yRGMD2Nivqc.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/yTSP6KaQaNE.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YuduIAz0Tck.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/yWko79s-anQ.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/YY-D7XBlLSI.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Y_fXEczgP08.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/z1liblrQEnc.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/z2E1XLxH7cQ.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/z3ZVrs5RkzE.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Z4xP6FL9oVk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Z62qAzwWIJM.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Z67Z6EBZzHk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Z7CL6PsmkdU.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/z9ue0qqZl0c.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZaH_6dNYqKU.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZARGOP8rGNg.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZB-bQ8Z6ygk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zBv-a82ipHQ.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zd0tuMtTFKQ.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Zd26sz_AYmc.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Zd8RUO017PM.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ze5UmoJRslk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZeLec1sL7EM.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zGu86jF8Gw8.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZgVhn7uTTDk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zID9AL9Fkho.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZJWyep9oQd8.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZKCrBNnPQoI.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zKSiMi8U21s.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zk_L24rG2iU.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZL_8-7u5GQc.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/znTsV8b44aA.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/znZHF-jOpT8.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zono1m7tv4w.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/Zoyj-aUyKKU.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zP22hzvfBsI.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZpveVpnf8CQ.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZW-dMkjfuMk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zw8OEkpQU-A.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zWUmolwz_0E.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/ZXEIBvlkOpU.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zZ-dM0KgVjA.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/zz3IObjLxZ0.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_--hGEcF-Co.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_0GiGMc2FtE.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_3NzxiQozXc.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_5jP7maXfwQ.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_IV23TAIAnE.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_rkPWNBEjfA.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_RVJDGqDk5A.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_t1xo1P235c.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_t7EPnCAy2o.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_VI34YKQ7Zk.mp4, file missing or incomplete.
# ⚠️ Skipping greenify_videos/_VPKxEgrKpY.mp4, file missing or incomplete.

# %% [markdown]
# move trimmed videos into subfolders based on their label

# %%
import os, shutil
import pandas as pd

subset = pd.read_csv("subset.csv")
trimmed_dir = "dataset/trimmed_videos"
train_dir = "dataset/train"

os.makedirs(train_dir, exist_ok=True)

for _, row in subset.iterrows():
    youtube_id = row['youtube_id']
    label = row['label'].replace(" ", "_")
    
    src = os.path.join(trimmed_dir, f"{youtube_id}_{label}.mp4")
    dst_dir = os.path.join(train_dir, label)
    os.makedirs(dst_dir, exist_ok=True)
    
    if os.path.exists(src):
        shutil.copy(src, dst_dir)

# %% [markdown]
# Create Train/Validation Split

# %%
from sklearn.model_selection import train_test_split
import glob

all_videos = glob.glob("dataset/train/*/*.mp4")
train_videos, val_videos = train_test_split(all_videos, test_size=0.2, random_state=42)

# Move val videos into dataset/val
val_dir = "dataset/val"
os.makedirs(val_dir, exist_ok=True)

for path in val_videos:
    label = os.path.basename(os.path.dirname(path))
    os.makedirs(os.path.join(val_dir, label), exist_ok=True)
    shutil.move(path, os.path.join(val_dir, label, os.path.basename(path)))

# %% [markdown]
# Load Dataset in PyTorch

# %%
import torch
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader

# Transformation (resize frames, convert to tensor)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# Load only the folder that actually has data
train_data = datasets.DatasetFolder(
    "dataset/train",
    loader=lambda x: x,
    extensions=(".mp4",),
    transform=transform
)

train_loader = DataLoader(train_data, batch_size=2, shuffle=True)

print("Classes found:", train_data.classes)
print("Number of samples:", len(train_data))
# Out:
# Classes found: ['catching_or_throwing_baseball']
# Number of samples: 158

# %% [markdown]
# Train a Simple Model

# %%
import torch
import torch.nn as nn
import torchvision.models as models

model = models.video.r3d_18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 4)  # 4 classes

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=R3D_18_Weights.KINETICS400_V1`. You can also use `weights=R3D_18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/r3d_18-b3b3357e.pth" to C:\Users\user/.cache\torch\hub\checkpoints\r3d_18-b3b3357e.pth
# 100%|███████████████████████████████████████████████████████████████████████████████| 127M/127M [00:47<00:00, 2.78MB/s]

# %% [markdown]
# Run a Few Epochs

# %%
import torch
import torchvision.models.video as models

# Load pretrained 3D ResNet
model = models.r3d_18(pretrained=True)

# Replace classifier head to match your current dataset
num_classes = 1   # you only have 1 class for now
model.fc = torch.nn.Linear(model.fc.in_features, num_classes)

print(model.fc)
# Out:
# Linear(in_features=512, out_features=1, bias=True)

# %%
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision import datasets

transform = transforms.Compose([
    transforms.Resize((112,112)),  # R3D expects 112x112 inputs
    transforms.ToTensor()
])

# Load dataset
train_data = datasets.DatasetFolder(
    "dataset/train",
    loader=lambda x: x,
    extensions=(".mp4",),
    transform=transform
)

train_loader = DataLoader(train_data, batch_size=2, shuffle=True)

# Get one batch
inputs, labels = next(iter(train_loader))
print("Input shape:", inputs.shape)  # should be [B, C, H, W]
print("Labels:", labels)

# Forward pass
outputs = model(inputs)
print("Output shape:", outputs.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 21
#      18 train_loader = DataLoader(train_data, batch_size=2, shuffle=True)
#      20 # Get one batch
# ---> 21 inputs, labels = next(iter(train_loader))
#      22 print("Input shape:", inputs.shape)  # should be [B, C, H, W]
#      23 print("Labels:", labels)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\datasets\folder.py:247, in DatasetFolder.__getitem__(self, index)
#     245 sample = self.loader(path)
#     246 if self.transform is not None:
# --> 247     sample = self.transform(sample)
#     248 if self.target_transform is not None:
#     249     target = self.target_transform(target)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\transforms\transforms.py:354, in Resize.forward(self, img)
#     346 def forward(self, img):
#     347     """
#     348     Args:
#     349         img (PIL Image or Tensor): Image to be scaled.
#    (...)
#     352         PIL Image or Tensor: Rescaled image.
#     353     """
# --> 354     return F.resize(img, self.size, self.interpolation, self.max_size, self.antialias)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\transforms\functional.py:465, in resize(img, size, interpolation, max_size, antialias)
#     459     if max_size is not None and len(size) != 1:
#     460         raise ValueError(
#     461             "max_size should only be passed if size specifies the length of the smaller edge, "
#     462             "i.e. size should be an int or a sequence of length 1 in torchscript mode."
#     463         )
# --> 465 _, image_height, image_width = get_dimensions(img)
#     466 if isinstance(size, int):
#     467     size = [size]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\transforms\functional.py:80, in get_dimensions(img)
#      77 if isinstance(img, torch.Tensor):
#      78     return F_t.get_dimensions(img)
# ---> 80 return F_pil.get_dimensions(img)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\transforms\_functional_pil.py:31, in get_dimensions(img)
#      29     width, height = img.size
#      30     return [channels, height, width]
# ---> 31 raise TypeError(f"Unexpected type {type(img)}")
#
# TypeError: Unexpected type <class 'str'>

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/39.0 MB 2.7 MB/s eta 0:00:15
#    - -------------------------------------- 1.3/39.0 MB 2.4 MB/s eta 0:00:16
#    - -------------------------------------- 1.8/39.0 MB 2.1 MB/s eta 0:00:18
#    -- ------------------------------------- 2.4/39.0 MB 2.5 MB/s eta 0:00:15
#    -- ------------------------------------- 2.9/39.0 MB 2.4 MB/s eta 0:00:16
#    --- ------------------------------------ 3.4/39.0 MB 2.6 MB/s eta 0:00:14
#    ---- ----------------------------------- 4.2/39.0 MB 2.5 MB/s eta 0:00:14
#    ---- ----------------------------------- 4.5/39.0 MB 2.6 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.2/39.0 MB 2.5 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.5/39.0 MB 2.5 MB/s eta 0:00:14
#    ------ --------------------------------- 6.3/39.0 MB 2.5 MB/s eta 0:00:14
#    ------ --------------------------------- 6.6/39.0 MB 2.5 MB/s eta 0:00:13
#    ------- -------------------------------- 7.3/39.0 MB 2.5 MB/s eta 0:00:13
#    -------- ------------------------------- 7.9/39.0 MB 2.6 MB/s eta 0:00:13
#    -------- ------------------------------- 8.7/39.0 MB 2.6 MB/s eta 0:00:12
#    --------- ------------------------------ 8.9/39.0 MB 2.6 MB/s eta 0:00:12
#    --------- ------------------------------ 9.7/39.0 MB 2.6 MB/s eta 0:00:12
#    ---------- ----------------------------- 10.2/39.0 MB 2.5 MB/s eta 0:00:12
#    ----------- ---------------------------- 10.7/39.0 MB 2.6 MB/s eta 0:00:12
#    ----------- ---------------------------- 11.3/39.0 MB 2.6 MB/s eta 0:00:11
#    ------------ --------------------------- 12.1/39.0 MB 2.6 MB/s eta 0:00:11
#    ------------ --------------------------- 12.3/39.0 MB 2.6 MB/s eta 0:00:11
#    ------------- -------------------------- 13.1/39.0 MB 2.6 MB/s eta 0:00:10
#    ------------- -------------------------- 13.6/39.0 MB 2.6 MB/s eta 0:00:10
#    -------------- ------------------------- 14.4/39.0 MB 2.6 MB/s eta 0:00:10
#    --------------- ------------------------ 15.2/39.0 MB 2.7 MB/s eta 0:00:09
#    ---------------- ----------------------- 15.7/39.0 MB 2.7 MB/s eta 0:00:09
#    ---------------- ----------------------- 16.5/39.0 MB 2.7 MB/s eta 0:00:09
#    ----------------- ---------------------- 17.3/39.0 MB 2.7 MB/s eta 0:00:08
#    ------------------ --------------------- 17.6/39.0 MB 2.8 MB/s eta 0:00:08
#    ------------------- -------------------- 18.6/39.0 MB 2.8 MB/s eta 0:00:08
#    -------------------- ------------------- 19.7/39.0 MB 2.8 MB/s eta 0:00:07
#    -------------------- ------------------- 20.2/39.0 MB 2.8 MB/s eta 0:00:07
#    --------------------- ------------------ 21.2/39.0 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 22.0/39.0 MB 2.9 MB/s eta 0:00:06
#    ----------------------- ---------------- 22.8/39.0 MB 2.9 MB/s eta 0:00:06
#    ------------------------ --------------- 23.9/39.0 MB 3.0 MB/s eta 0:00:06
#    ------------------------- -------------- 24.4/39.0 MB 3.0 MB/s eta 0:00:05
#    ------------------------- -------------- 25.2/39.0 MB 3.0 MB/s eta 0:00:05
#    -------------------------- ------------- 26.2/39.0 MB 3.0 MB/s eta 0:00:05
#    --------------------------- ------------ 27.0/39.0 MB 3.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.8/39.0 MB 3.1 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.8/39.0 MB 3.1 MB/s eta 0:00:04
#    ------------------------------ --------- 29.4/39.0 MB 3.1 MB/s eta 0:00:04
#    ------------------------------ --------- 30.1/39.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 30.9/39.0 MB 3.1 MB/s eta 0:00:03
#    -------------------------------- ------- 31.5/39.0 MB 3.1 MB/s eta 0:00:03
#    --------------------------------- ------ 32.5/39.0 MB 3.2 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.6/39.0 MB 3.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.6/39.0 MB 3.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.6/39.0 MB 3.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.4/39.0 MB 3.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.9/39.0 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 37.0/39.0 MB 3.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/39.0 MB 3.2 MB/s eta 0:00:01
#    -------------------------------------- - 38.0/39.0 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.0 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 3.1 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.9 MB 4.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/12.9 MB 3.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.8/12.9 MB 3.0 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.9 MB 3.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.4/12.9 MB 3.2 MB/s eta 0:00:03
#    ------------ --------------------------- 4.2/12.9 MB 3.3 MB/s eta 0:00:03
#    --------------- ------------------------ 5.0/12.9 MB 3.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.8/12.9 MB 3.4 MB/s eta 0:00:03
#    ------------------- -------------------- 6.3/12.9 MB 3.3 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.9 MB 3.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.3/12.9 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.9 MB 3.2 MB/s eta 0:00:02
#    -------------------------- ------------- 8.7/12.9 MB 3.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.2/12.9 MB 3.1 MB/s eta 0:00:02
#    ------------------------------ --------- 9.7/12.9 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 10.7/12.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.3/12.9 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 3.2 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# Successfully installed numpy-2.2.6 opencv-python-4.12.0.88
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# d2l 1.0.3 requires numpy==1.23.5, but you have numpy 2.2.6 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.2.6 which is incompatible.
# scipy 1.10.1 requires numpy<1.27.0,>=1.19.5, but you have numpy 2.2.6 which is incompatible.
# tensorflow-intel 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 2.2.6 which is incompatible.
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install opencv-python-headless
# Out:
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from opencv-python-headless) (2.2.6)
# Downloading opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl (38.9 MB)
#    ---------------------------------------- 0.0/38.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.9 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.9 MB 3.4 MB/s eta 0:00:12
#     --------------------------------------- 0.8/38.9 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.3/38.9 MB 1.6 MB/s eta 0:00:24
#    - -------------------------------------- 1.8/38.9 MB 1.9 MB/s eta 0:00:20
#    -- ------------------------------------- 2.6/38.9 MB 2.2 MB/s eta 0:00:17
#    --- ------------------------------------ 3.1/38.9 MB 2.2 MB/s eta 0:00:17
#    --- ------------------------------------ 3.7/38.9 MB 2.3 MB/s eta 0:00:16
#    ---- ----------------------------------- 4.5/38.9 MB 2.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.0/38.9 MB 2.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.8/38.9 MB 2.6 MB/s eta 0:00:13
#    ------ --------------------------------- 6.6/38.9 MB 2.7 MB/s eta 0:00:13
#    ------- -------------------------------- 7.1/38.9 MB 2.8 MB/s eta 0:00:12
#    -------- ------------------------------- 8.1/38.9 MB 2.9 MB/s eta 0:00:11
#    --------- ------------------------------ 8.9/38.9 MB 2.9 MB/s eta 0:00:11
#    --------- ------------------------------ 9.4/38.9 MB 3.0 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.5/38.9 MB 3.0 MB/s eta 0:00:10
#    ----------- ---------------------------- 11.0/38.9 MB 3.0 MB/s eta 0:00:10
#    ------------ --------------------------- 11.8/38.9 MB 3.1 MB/s eta 0:00:09
#    ------------ --------------------------- 12.6/38.9 MB 3.1 MB/s eta 0:00:09
#    ------------- -------------------------- 13.4/38.9 MB 3.1 MB/s eta 0:00:09
#    -------------- ------------------------- 14.2/38.9 MB 3.1 MB/s eta 0:00:08
#    --------------- ------------------------ 14.9/38.9 MB 3.2 MB/s eta 0:00:08
#    --------------- ------------------------ 15.5/38.9 MB 3.2 MB/s eta 0:00:08
#    ---------------- ----------------------- 16.3/38.9 MB 3.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.8/38.9 MB 3.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 17.3/38.9 MB 3.1 MB/s eta 0:00:07
#    ------------------ --------------------- 17.8/38.9 MB 3.1 MB/s eta 0:00:07
#    ------------------ --------------------- 18.4/38.9 MB 3.0 MB/s eta 0:00:07
#    ------------------- -------------------- 18.9/38.9 MB 3.1 MB/s eta 0:00:07
#    -------------------- ------------------- 19.7/38.9 MB 3.1 MB/s eta 0:00:07
#    -------------------- ------------------- 20.2/38.9 MB 3.1 MB/s eta 0:00:07
#    --------------------- ------------------ 21.0/38.9 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.5/38.9 MB 3.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 22.0/38.9 MB 3.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 22.5/38.9 MB 3.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 22.5/38.9 MB 3.0 MB/s eta 0:00:06
#    ------------------------ --------------- 23.6/38.9 MB 3.0 MB/s eta 0:00:06
#    ------------------------- -------------- 24.4/38.9 MB 3.0 MB/s eta 0:00:05
#    ------------------------- -------------- 24.6/38.9 MB 3.0 MB/s eta 0:00:05
#    ------------------------- -------------- 25.2/38.9 MB 3.0 MB/s eta 0:00:05
#    -------------------------- ------------- 25.7/38.9 MB 3.0 MB/s eta 0:00:05
#    --------------------------- ------------ 26.5/38.9 MB 2.9 MB/s eta 0:00:05
#    --------------------------- ------------ 27.0/38.9 MB 2.9 MB/s eta 0:00:05
#    ---------------------------- ----------- 28.0/38.9 MB 3.0 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.3/38.9 MB 3.0 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.8/38.9 MB 2.9 MB/s eta 0:00:04
#    ------------------------------ --------- 29.6/38.9 MB 2.9 MB/s eta 0:00:04
#    ------------------------------- -------- 30.4/38.9 MB 3.0 MB/s eta 0:00:03
#    -------------------------------- ------- 31.2/38.9 MB 3.0 MB/s eta 0:00:03
#    -------------------------------- ------- 31.7/38.9 MB 3.0 MB/s eta 0:00:03
#    --------------------------------- ------ 32.5/38.9 MB 3.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.3/38.9 MB 3.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.8/38.9 MB 3.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.3/38.9 MB 3.0 MB/s eta 0:00:02
#    ------------------------------------ --- 35.1/38.9 MB 3.0 MB/s eta 0:00:02
#    ------------------------------------ --- 35.7/38.9 MB 3.0 MB/s eta 0:00:02
#    ------------------------------------- -- 36.2/38.9 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.9 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/38.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 38.9/38.9 MB 2.9 MB/s eta 0:00:00
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.12.0.88
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.8/15.8 MB 2.8 MB/s eta 0:00:06
#    --- ------------------------------------ 1.6/15.8 MB 2.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.1/15.8 MB 2.8 MB/s eta 0:00:05
#    ------ --------------------------------- 2.6/15.8 MB 2.7 MB/s eta 0:00:05
#    -------- ------------------------------- 3.4/15.8 MB 3.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/15.8 MB 3.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.7/15.8 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 5.2/15.8 MB 3.0 MB/s eta 0:00:04
#    -------------- ------------------------- 5.8/15.8 MB 3.0 MB/s eta 0:00:04
#    --------------- ------------------------ 6.3/15.8 MB 3.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 6.8/15.8 MB 2.9 MB/s eta 0:00:04
#    ------------------ --------------------- 7.3/15.8 MB 2.8 MB/s eta 0:00:04
#    ------------------- -------------------- 7.9/15.8 MB 2.7 MB/s eta 0:00:03
#    --------------------- ------------------ 8.4/15.8 MB 2.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.9/15.8 MB 2.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.9/15.8 MB 2.7 MB/s eta 0:00:03
#    ------------------------ --------------- 9.7/15.8 MB 2.6 MB/s eta 0:00:03
#    ------------------------- -------------- 10.0/15.8 MB 2.6 MB/s eta 0:00:03
#    -------------------------- ------------- 10.5/15.8 MB 2.5 MB/s eta 0:00:03
#    --------------------------- ------------ 11.0/15.8 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.5/15.8 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 12.1/15.8 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 12.8/15.8 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 13.1/15.8 MB 2.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.6/15.8 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.2/15.8 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.8 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 2.5 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# d2l 1.0.3 requires numpy==1.23.5, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import torch
from torch.utils.data import Dataset
import os

class VideoDataset(Dataset):
    def __init__(self, root_dir, transform=None, frames_per_clip=16):
        self.root_dir = root_dir
        self.transform = transform
        self.frames_per_clip = frames_per_clip

        # Collect all video paths with class labels
        self.samples = []
        classes = sorted(os.listdir(root_dir))
        self.class_to_idx = {cls_name: i for i, cls_name in enumerate(classes)}

        for cls_name in classes:
            cls_path = os.path.join(root_dir, cls_name)
            if not os.path.isdir(cls_path):
                continue
            for fname in os.listdir(cls_path):
                if fname.endswith(".mp4"):
                    path = os.path.join(cls_path, fname)
                    self.samples.append((path, self.class_to_idx[cls_name]))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label = self.samples[idx]
        cap = cv2.VideoCapture(path)
        frames = []
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

        # Pick evenly spaced frames
        indices = torch.linspace(0, total_frames - 1, self.frames_per_clip).long().tolist()

        for i in indices:
            cap.set(cv2.CAP_PROP_POS_FRAMES, i)
            ret, frame = cap.read()
            if not ret:
                break
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # BGR → RGB
            frame = torch.tensor(frame).permute(2, 0, 1)    # HWC → CHW
            if self.transform:
                frame = self.transform(frame)
            frames.append(frame)

        cap.release()

        # Stack frames → shape [T, C, H, W]
        video = torch.stack(frames)
        return video, label

# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

transform = transforms.Compose([
    transforms.Resize((112, 112)),  # match R3D input
    transforms.ConvertImageDtype(torch.float32),
    transforms.Normalize(mean=[0.5], std=[0.5])  # quick normalize
])

train_dataset = VideoDataset("dataset/train", transform=transform)
train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)

videos, labels = next(iter(train_loader))
print("Video batch shape:", videos.shape)  # [B, T, C, H, W]
print("Labels:", labels)
# Out:
# Video batch shape: torch.Size([2, 16, 3, 112, 112])
# Labels: tensor([0, 0])
